# %% [markdown]
# # **Challenge - FIAP - 2026 - ClickBus**

# %% [markdown]
# ## Camada Bronze: Ingestão e Integridade
#
# Realizar a extração dos dados brutos da ClickBus (~1.7M de linhas) e garantir a integridade da ingestão. Esta camada preserva o dado original sem transformações, servindo como a "fonte da verdade" para o pipeline.
#
# Os desafios de Segmentação (1), Previsão de Compra (2) e Previsão de Trecho (3) serão processados nas camadas subsequentes (Silver e Gold).

# %%
import pandas as pd
import gdown

from google.colab import drive

drive.mount('/content/drive')

# %%
url_df = "https://drive.google.com/uc?id=1H43N5nTAWX7TdPIkX1G3nf50bxTw18JD"
out_df = "challenge.csv"

gdown.download(url_df, out_df, quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1H43N5nTAWX7TdPIkX1G3nf50bxTw18JD
# From (redirected): https://drive.google.com/uc?id=1H43N5nTAWX7TdPIkX1G3nf50bxTw18JD&confirm=t&uuid=39d69ee4-a7cf-46c0-9267-8200a9ccf5fb
# To: /content/challenge.csv
# 100%|██████████| 660M/660M [00:08<00:00, 78.9MB/s]
# 'challenge.csv'

# %%
df_bronze = pd.read_csv('/content/challenge.csv')
df_bronze.head()
# Out:
#                                  nk_ota_localizer_id  \
# 0  bc02d5245bec63b30ff1102fa273fc03f58bc9cc3f674e...
# 1  5432f12612dd5d749b3be880e779989cf63b5efa4bcc4e...
# 2  fb3caed9b2f1b6016d45ccddb19095476e61a2c85faa8e...
# 3  4dc44a6dd592b702feccb493d192210c86965aee684529...
# 4  aa34ed7fd0a6b405df2df1bf9f8d68e6df9b9a868a6181...
#
#                                           fk_contact date_purchase  \
# 0  a7218ff4ee7d37d48d2b4391b955627cb089870b934912...    2018-12-26
# 1  37228485e0dc83d84d1bcd1bef3dc632301bf6cb22c8b5...    2018-12-05
# 2  3467ec081e2421e72c96e7203b929d21927fd00b6b5f28...    2018-12-21
# 3  ab3251a2be0f69713b8f97b0e9d1579e31551f4fd4facf...    2018-12-06
# 4  ceea0de820a6379f2c4215bddaec66c33994b304607e56...    2021-02-23
#
#   time_purchase                             place_origin_departure  \
# 0      15:33:35  6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...
# 1      15:07:57  10e4e7caf8b078429bb1c80b1a10118ac6f963eff098fd...
# ...

# %%
df_bronze.shape
# Out:
# (1741344, 12)

# %%
df_bronze.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1741344 entries, 0 to 1741343
# Data columns (total 12 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   nk_ota_localizer_id             object
#  1   fk_contact                      object
#  2   date_purchase                   object
#  3   time_purchase                   object
#  4   place_origin_departure          object
#  5   place_destination_departure     object
#  6   place_origin_return             object
#  7   place_destination_return        object
#  8   fk_departure_ota_bus_company    object
#  9   fk_return_ota_bus_company       object
#  10  gmv_success                     float64
#  11  total_tickets_quantity_success  int64
# dtypes: float64(1), int64(1), object(10)
# memory usage: 159.4+ MB

# %%
df_bronze.isnull().sum()
# Out:
# nk_ota_localizer_id               0
# fk_contact                        0
# date_purchase                     0
# time_purchase                     0
# place_origin_departure            0
# place_destination_departure       0
# place_origin_return               0
# place_destination_return          0
# fk_departure_ota_bus_company      0
# fk_return_ota_bus_company         0
# gmv_success                       0
# total_tickets_quantity_success    0
# dtype: int64

# %%
print("--- Check de Integridade Bronze ---")
print(f"Shape: {df_bronze.shape}")
print(f"Período: {df_bronze['date_purchase'].min()} até {df_bronze['date_purchase'].max()}")

print(f"Duplicatas: {df_bronze.duplicated().sum()}")
print("-" * 30)

print(f"Tipos de Dados:\n{df_bronze.dtypes}")
print("-" * 30)

df_bronze.to_parquet('/content/drive/MyDrive/Portifólio DS Vini/Challenge_ClickBus_2025/data/bronze/clickbus_bronze.parquet', index=False)
print("Bronze salvo com sucesso em formato Parquet (Tipagem preservada).")
print("Local: /content/drive/MyDrive/Portifólio DS Vini/Challenge_ClickBus_2025/data/bronze/clickbus_bronze.parquet")
# Out:
# --- Check de Integridade Bronze ---
# Shape: (1741344, 12)
# Período: 2013-09-12 até 2024-04-01
# Duplicatas: 0
# ------------------------------
# Tipos de Dados:
# nk_ota_localizer_id                object
# fk_contact                         object
# date_purchase                      object
# time_purchase                      object
# place_origin_departure             object
# place_destination_departure        object
# place_origin_return                object
# place_destination_return           object
# fk_departure_ota_bus_company       object
# fk_return_ota_bus_company          object
# gmv_success                       float64
# total_tickets_quantity_success      int64
# dtype: object
# ------------------------------
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Bronze salvo com sucesso em formato Parquet (Tipagem preservada).
# ...
